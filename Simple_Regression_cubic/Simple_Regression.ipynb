# %%
# import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# %matplotlib inline

# %%
# read data
df = pd.read_csv('../Data_Preparation/data_fcc.csv', index_col=0)
df
# Out:
#                              Potential Element  1_0_0 surface energy  \
# 0                         Ag.eam.alloy      Ag              0.948562
# 1                       Al03.eam.alloy      Al              0.604481
# 2                       Al03.eam.alloy      Al              0.604481
# 3                       Al99.eam.alloy      Al              0.948917
# 4                       AlCu.eam.alloy      Al              0.584038
# 5                       AlCu.eam.alloy      Cu              1.260765
# 6                 alpb-setfl.eam.alloy      Al              0.952294
# 7                 alpb-setfl.eam.alloy      Al              0.952294
# 8                 alpb-setfl.eam.alloy      Pb              0.569756
# 9                    Al_zhou.eam.alloy      Al              0.869093
# 10         Au-Grochola-JCP05.eam.alloy      Au              1.305827
# 11                      CoAl.eam.alloy      Co              1.191392
# 12                      CoAl.eam.alloy      Al              0.861699
# ...

# %%
# plot all the data
sns.pairplot(df.loc[:,df.dtypes == 'float64'])
