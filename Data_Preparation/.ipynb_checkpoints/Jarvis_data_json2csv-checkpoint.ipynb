# %%
# import modules
import urllib.request
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# %matplotlib inline

# %%
# Load the JARVIS dataset
url = 'https://ndownloader.figshare.com/files/14146319' 
urllib.request.urlretrieve(url, 'jff2.json') 
f=open('jff2.json','r')
data=json.load(f)
f.close()

# Show the first item
data[0]
# Out:
# {'c44': 25.1,
#  'Gv': 29.6,
#  'search': 'Ag',
#  'name': 'JLMP-1079',
#  'surf_val': [0.8582640971273426,
#   0.9334963319196496,
#   0.9360461382184894,
#   0.9419095687284446,
#   0.9802042233627004,
#   0.9875446840480956,
#   1.0120634294466684,
#   1.0126231880823566,
#   1.0241538763302507,
#   1.0315901848682645,
#   1.0318271257831195,
#   1.0331286888257398,
#   1.0344297141291043,
#   1.0388709097092674,
#   1.040277640596931,
#   1.042494119906149,
#   1.04453679643896,
#   1.0450598648770613,
#   1.045076130339553,
#   1.0469310544190567,
#   1.0491015867538047,
#   1.0495494553198788,
#   1.0534717916897114,
#   1.0535201391639715,
#   1.054233162444997,
#   1.0579157863887743,
#   1.0595676718662346,
#   1.0601381085497692,
#   1.109580394178689],
#  'defect_val': [1.086429999999973, 1.0916199999999434],
#  'defect_name': ['vacancy_1_mult-2_sitespecie-Ag',
#   'vacancy_2_mult-2_sitespecie-Ag'],
#  'surf_name': ['0_0_1',
#   '2_0_3',
#   '2_0_1',
#   '1_0_1',
#   '3_0_2',
#   '1_0_3',
#   '3_1_1',
#   '3_0_1',
#   '3_1_3',
#   '3_-1_1',
#   '3_1_0',
#   '3_2_1',
#   '3_3_1',
#   '1_0_0',
#   '2_2_1',
#   '3_-1_3',
#   '3_-1_2',
#   '3_3_2',
#   '3_2_2',
#   '2_-1_3',
#   '3_2_0',
#   '3_2_3',
#   '1_1_1',
#   '1_0_2',
#   '3_1_2',
#   '2_-1_2',
#   '3_-1_0',
#   '2_2_3',
#   '1_1_0'],
#  'Bv': 103.6,
#  'fenp': -2.847933,
#  'ff': 'Ag.eam.alloy',
#  'c12': 93.0,
#  'c13': 73.4,
#  'formula': 'Ag',
#  'c11': 146.7,
#  'sg': 'P6_3/mmc'}

# %%
# Create the space group array
sg_array = []
for d in data:
    if d['sg'] is not '':
        sg_array.append(d['sg'])
    else:
        sg_array.append('')

# Count the number of points for each space group
sg_hist = Counter()
for sg in sg_array:
     sg_hist[sg] += 1

# Sort the space groups from the largest number of points to the smalest
sg_sorted = [item[0] for item in sorted(sg_hist.items() , reverse=True, key=lambda x: x[1])]

# Plot the corresponding histogram
plt.rcParams['figure.figsize'] = [15, 12]
plt.title("Number of data point corresponding to each space group")
sns.set(style="darkgrid")
ax = sns.countplot(y=sg_array, order = sg_sorted)

# %%
# Set Bravais lattices corresponding to the space groups explored above
Bravais_lattices = {'cubic' : {'Fm-3m','Im-3m','Pm-3m','Fd-3m','Pm-3n','Ia-3d','F-43m','P-43m','I-43m','Fm3'},
                    'hexagonal' : {'P6_3/mmc','P6/mmm','P6_3mc','P6_322'},
                    'tetragonal' : {'I4/mmm','P4/mmm','P4_2/mnm','I4/mcm','I4/m','I4_1/amd','I-4'},
                    'triclinic' : {'P-1','P1'},
                    'rhombohedral' : {'R-3m','P-3m1'},
                    'orthorhombic' : {'Cmce','Pnma','Cmmm','Cmcm','Pnnm','Immm','Pmmn','Fmmm','Cmme','Pbcm','P2_12_12_1'},
                    'monoclinic' : {'P2/m','C2/m','P2_1/c','P2_1/m','Pm','Pc','C2/c','P2/c','Cc','P2_1'},
                    'trigonal' : {'P3m1','R-3'}}

# define function retuning Bravais lattice corresponding to specified space group
def get_lattice(space_group):
    result = np.nan
    for bl in Bravais_lattices.items():
        if space_group in bl[1]:
            result = bl[0]
    return result

# Create the Bravais lattice array
bl_array = []
for d in data:
    bl_array.append(get_lattice(d['sg']))

# Count the number of points for each Bravais lattice
bl_hist = Counter()
for bl in bl_array:
     bl_hist[bl] += 1            
            
# Sort the Bravais lattices from the largest number of points to the smalest
bl_sorted = [item[0] for item in sorted(bl_hist.items() , reverse=True, key=lambda x: x[1])]         
            
# Plot the corresponding histogram
plt.rcParams['figure.figsize'] = [15, 5]
plt.title("Number of data point corresponding to each Bravais lattice")
sns.set(style="darkgrid")
ax = sns.countplot(x=bl_array, order=bl_sorted)

# %%
# determine number of surfaces computed for materials with cubic lattices
sn_array = [len(d['surf_name']) for d in data if get_lattice(d['sg']) == 'cubic']

# Count the number of points for each number of surfaces
sn_hist = Counter()
for sn in sn_array:
     sn_hist[sn] += 1            
            
# Sort the Bravais lattices from the largest number of points to the smalest
sn_sorted = [item[0] for item in sorted(sn_hist.items() , reverse=True, key=lambda x: x[1])]         
            
# Plot the corresponding histogram
plt.rcParams['figure.figsize'] = [15, 5]
plt.title("Number of data point corresponding to each nuber of surfaces for materials with cubic lattices")
sns.set(style="darkgrid")
ax = sns.countplot(x=sn_array, order=sn_sorted)

# %%
# determine number of vacancy energies computed for materials with cubic lattices and 13 surfaces
ve_array = [len(d['defect_val']) for d in data if get_lattice(d['sg']) == 'cubic' and len(d['surf_name']) == 13]

# Count the number of points for each number of surfaces
ve_hist = Counter()
for ve in ve_array:
     ve_hist[ve] += 1            
            
# Sort the Bravais lattices from the largest number of points to the smalest
ve_sorted = [item[0] for item in sorted(ve_hist.items() , reverse=True, key=lambda x: x[1])]         
            
# Plot the corresponding histogram
plt.rcParams['figure.figsize'] = [15, 5]
plt.title("Number of data point corresponding to number of vacancy energies computed for materials with cubic lattices and 13 surfaces")
sns.set(style="darkgrid")
ax = sns.countplot(x=ve_array, order=ve_sorted)

# %%
# show all the materials with 1 positive vacancy energy
import pprint
pprint.pprint([{d['formula'] : d['defect_val']}  for d in data 
               if get_lattice(d['sg']) == 'cubic' 
               and len(d['surf_name']) == 13 
               and len(d['defect_val']) == 1 
               and d['defect_val'][0] > 0.0])
# Out:
# 188

# %%
# check the number of unique surfaces
surfaces = set()
for d in data: 
    if get_lattice(d['sg']) == 'cubic' and len(d['surf_name']) == 13 and len(d['defect_val']) == 1 and d['defect_val'][0] > 0.0:
        for s in d['surf_name']:
            surfaces.add(s) 
print(surfaces)
# Out:
# {'3_2_2', '2_1_1', '3_1_0', '2_1_0', '1_1_0', '3_3_2', '1_1_1', '3_1_1', '3_2_1', '1_0_0', '3_2_0', '2_2_1', '3_3_1'}

# %%
# create a pandas dataframe
df_cubic = pd.DataFrame(columns=['Space group (0-bcc, 1-fcc)','1_0_0 surface energy','1_1_0 surface energy','1_1_1 surface energy',
                                 '2_1_0 surface energy','2_1_1 surface energy','2_2_1 surface energy',
                                 '3_1_0 surface energy','3_1_1 surface energy','3_2_0 surface energy',
                                 '3_2_1 surface energy','3_2_2 surface energy','3_3_1 surface energy',
                                 '3_3_2 surface energy','c_1_1 elastic constant','c_1_2 elastic constant',
                                 'c_1_3  elastic constant', 'c_4_4  elastic constant','Shear modulus',
                                 'Bulk modulus','Cohesive energy','Vacancy formation energy'])

j = 0
for d in data: 
    if get_lattice(d['sg']) == 'cubic' and len(d['surf_name']) == 13 and len(d['defect_val']) == 1 and d['defect_val'][0] > 0.0 and d['Bv'] > 0.0:
        df_cubic.loc[j] = [int(d['sg'] == 'Fm-3m'), d['surf_val'][d['surf_name'].index('1_0_0')], d['surf_val'][d['surf_name'].index('1_1_0')], d['surf_val'][d['surf_name'].index('1_1_1')], 
                         d['surf_val'][d['surf_name'].index('2_1_0')], d['surf_val'][d['surf_name'].index('2_1_1')], d['surf_val'][d['surf_name'].index('2_2_1')],
                         d['surf_val'][d['surf_name'].index('3_1_0')], d['surf_val'][d['surf_name'].index('3_1_1')], d['surf_val'][d['surf_name'].index('3_2_0')],
                         d['surf_val'][d['surf_name'].index('3_2_1')], d['surf_val'][d['surf_name'].index('3_2_2')], d['surf_val'][d['surf_name'].index('3_3_1')],
                         d['surf_val'][d['surf_name'].index('3_3_2')], d['c11'], d['c12'], 
                         d['c13'], d['c44'], d['Gv'], d['Bv'], -d['fenp'], d['defect_val'][0]]
        j += 1

df_cubic
# Out:
#      Space group (0-bcc, 1-fcc)  1_0_0 surface energy  1_1_0 surface energy  \
# 0                           1.0              0.948562              1.024136
# 1                           1.0              0.604481              0.786499
# 2                           1.0              0.604481              0.786499
# 3                           0.0             -0.503541              0.341313
# 4                           1.0              0.948917              1.013094
# 5                           0.0              0.350584              0.525458
# 6                           1.0              0.584038              0.630810
# 7                           0.0              1.262499              1.084682
# 8                           1.0              1.260765              1.360613
# 9                           1.0              0.952294              1.044245
# 10                          1.0              0.952294              1.044245
# 11                          1.0              0.569756              0.659956
# 12                          0.0              0.426949              0.579559
# 13                          0.0              0.088356              0.317332
# 14                          1.0              0.869093              0.957824
# 15                          1.0              1.305827              1.543625
# 16                          1.0              1.191392              1.335416
# 17                          1.0              0.861699              0.968888
# 18                          1.0              0.861699              0.968888
# 19                          1.0              2.486648              2.612595
# 20                          1.0              1.355675              1.485404
# 21                          1.0              0.948562              1.024136
# 22                          0.0              0.388006              0.899369
# 23                          1.0              1.024669              1.135927
# 24                          1.0              0.948607              1.024143
# 25                          1.0              1.355742              1.726266
# 26                          1.0              1.355742              1.485490
# 27                          1.0              1.518055              1.647225
# 28                          0.0              2.094740              1.836342
# 29                          0.0              1.074405              0.849696
# ..                          ...                   ...                   ...
# 154                         1.0              1.491933              1.488181
# 155                         0.0              1.521434              1.416075
# 156                         1.0              1.388068              1.502863
# 157                         0.0              1.183195              0.941232
# 158                         1.0              1.563326              1.688583
# 159                         1.0              0.983223              1.090589
# 160                         0.0              0.455826              0.579935
# 161                         1.0              0.925314              1.034074
# 162                         1.0              0.917497              1.052294
# 163                         1.0              0.917497              1.052294
# 164                         1.0              1.013378              1.112975
# 165                         0.0              0.910559              1.005166
# 166                         1.0              1.573642              1.753661
# 167                         1.0             -0.137484              1.625809
# 168                         0.0              1.701541              1.429534
# 169                         0.0              2.476398              2.142844
# 170                         1.0              2.314831              2.462453
# 171                         0.0              0.149741              1.095325
# 172                         1.0              1.882115              2.071313
# 173                         1.0              0.385306              0.426360
# 174                         1.0              2.079120              2.271061
# 175                         1.0              1.742603              1.914833
# 176                         0.0              1.286628              1.513948
# 177                         1.0              1.635706              1.803524
# 178                         1.0              2.182974              2.402577
# 179                         0.0              1.204683              1.311674
# 180                         1.0              2.786738              2.974402
# 181                         0.0              2.985782              2.557614
# 182                         1.0              1.377955              1.508439
# 183                         0.0              1.281694              1.297385
#
#      1_1_1 surface energy  2_1_0 surface energy  2_1_1 surface energy  \
# 0                0.864925              1.070158              0.998082
# 1                0.593439              0.842820              0.753661
# 2                0.593439              0.842820              0.820114
# 3                0.892009              0.078823              0.699091
# 4                0.874776              1.053030              0.998492
# 5                0.647399              0.603678              0.579261
# 6                0.525976              0.662280              0.608787
# 7                1.399032              1.258725              1.308617
# 8                1.169975              1.416056              1.333797
# 9                0.881014              1.086586              1.070604
# 10               1.339422              1.086586              1.070715
# 11               0.579540              0.664830              0.667650
# 12               0.788985              0.469034              0.701066
# 13               0.924082              0.435761              0.826525
# 14               0.832572              0.992483              0.987090
# 15               1.193710              1.617133              1.531697
# 16               1.795654              1.442407              1.338387
# 17               0.829731              1.009581              0.945068
# 18               0.829731              1.009581              0.944591
# 19               2.333702              2.696837              2.753001
# 20               1.243161              1.554216              1.513528
# 21               0.864925              1.070158              0.996321
# 22               1.144628              0.535754              0.981505
# 23               0.930815              1.192430              1.154034
# 24               1.286916              1.070146              1.043412
# 25               1.243222              1.554305              1.440600
# 26               1.870490              1.554305              1.512346
# 27               1.449797              1.708112              1.634772
# 28               2.201926              2.057268              2.078537
# 29               1.155109              0.948654              1.032915
# ..                    ...                   ...                   ...
# 154              1.316222              1.548164              1.478813
# 155              1.574118              1.353143              1.474810
# 156              1.232599              1.577166              1.442050
# 157              1.605721              1.064468              1.562005
# 158              1.941206              1.725315              1.676979
# 159              0.908338              1.140299              1.054004
# 160              1.097377              0.694996              0.894163
# 161              0.909157              1.067705              1.067429
# 162              0.879590              1.105053              1.018578
# 163              0.879590              1.105053              1.074084
# 164              0.901769              1.170534              1.057911
# 165              1.810418              1.128502              1.517121
# 166              2.193875              1.823257              1.792417
# 167              1.253167              0.073708              1.528727
# 168              1.862213              1.662786              1.693303
# 169              2.769441              2.453838              2.530848
# 170              1.916947              2.619901              2.318402
# 171              2.058241              1.310259              2.008713
# 172              2.631176              2.161848              2.132226
# 173              0.347386              0.446574              0.406781
# 174              2.009454              2.341062              2.321343
# 175              1.786406              1.898206              1.930894
# 176              1.924654              1.519443              1.855349
# 177              1.518004              1.883188              1.838402
# 178              2.080449              2.491624              2.465919
# 179              1.583815              1.295406              1.501508
# 180              2.302057              3.168671              2.956799
# 181              3.323388              2.939530              3.024443
# 182              1.260110              1.605096              1.478879
# 183              1.568083              1.321100              1.579918
#
#      2_2_1 surface energy  3_1_0 surface energy  3_1_1 surface energy  \
# 0                0.980901              1.055143              1.043093
# 1                0.729973              0.789371              0.813084
# 2                0.730004              0.789371              0.825851
# 3                0.866951             -0.077293              0.502300
# 4                1.057675              1.042416              1.018868
# 5                0.623557              0.635626              0.630956
# 6                0.599046              0.651650              0.627484
# 7                1.358863              0.997643              1.354902
# 8                1.312432              1.399060              1.356594
# 9                1.004252              1.068335              1.056793
# 10               1.004216              1.068335              1.096973
# 11               0.639377              0.636377              0.644858
# 12               0.732755              0.457440              0.669078
# 13               0.904694              0.505800              0.808902
# 14               1.003116              0.977126              0.962502
# 15               1.566992              1.553787              1.504888
# 16               1.368520              1.395559              1.496865
# 17               0.934175              0.984219              0.966021
# 18               0.934159              0.984219              1.058167
# 19               2.633053              2.729627              2.835423
# 20               1.417326              1.529036              1.548116
# 21               1.058122              1.055143              1.021323
# 22               1.097027              0.520073              1.100039
# 23               1.073914              1.165329              1.128252
# 24               0.980958              1.055115              1.066365
# 25               1.417218              1.529119              1.479407
# 26               1.417209              1.528482              1.479336
# 27               1.612223              1.691598              1.724554
# 28               2.112418              2.107817              2.141011
# 29               1.067997              0.998705              1.074146
# ..                    ...                   ...                   ...
# 154              1.458912              1.564547              1.500538
# 155              1.551283              1.260579              1.545340
# 156              1.418468              1.548140              1.522230
# 157              1.536393              0.954119              1.378709
# 158              1.605398              1.708317              1.690801
# 159              1.036435              1.115848              1.132655
# 160              1.176290              0.664886              0.945324
# 161              1.085557              1.046579              1.041090
# 162              0.997419              1.069767              1.050312
# 163              1.099200              1.069767              1.050312
# 164              1.037108              1.144359              1.150265
# 165              1.770763              1.001948              1.746877
# 166              1.824197              1.786649              1.948885
# 167              1.645749              0.165744              1.608980
# 168              1.746204              1.723227              1.765631
# 169              2.605798              2.503413              2.601452
# 170              2.254214              2.578183              2.440292
# 171              2.048762              1.434502              1.923577
# 172              2.168335              2.126357              2.168455
# 173              0.399661              0.436251              0.421390
# 174              2.221504              2.302461              2.309186
# 175              1.910415              1.894065              1.926640
# 176              1.930321              1.670082              1.852780
# 177              1.725999              1.846606              1.918054
# 178              2.332169              2.447711              2.406919
# 179              1.529829              1.422798              1.541772
# 180              2.714541              3.113760              2.944507
# 181              3.119087              3.035329              3.120041
# 182              1.444065              1.549548              1.539039
# 183              1.514675              1.246709              1.526542
#
#      3_2_0 surface energy  ...  3_3_1 surface energy  3_3_2 surface energy  \
# 0                1.064618  ...              1.007580              0.971339
# 1                0.831645  ...              0.772427              0.717488
# 2                0.834879  ...              0.847928              0.717473
# 3                0.051526  ...              0.721606              0.930388
# 4                1.050692  ...              1.006455              0.973985
# 5                0.568199  ...              0.606849              0.638261
# 6                0.657184  ...              0.615999              0.593059
# 7                1.088034  ...              1.323872              1.387659
# 8                1.410780  ...              1.343084              1.271137
# 9                1.085176  ...              1.034297              0.967778
# 10               1.085176  ...              1.148812              0.993109
# 11               0.668659  ...              0.651086              0.634972
# 12               0.583985  ...              0.722952              0.728845
# 13               0.391740  ...              0.858357              0.991238
# 14               0.991406  ...              0.955820              0.904078
# 15               1.602660  ...              1.491257              1.392588
# 16               1.417360  ...              1.488518              1.187296
# 17               1.005364  ...              0.958318              0.927164
# 18               1.005208  ...              0.955669              0.927168
# 19               2.716925  ...              2.683608              2.598866
# 20               1.545589  ...              1.455957              1.402973
# 21               1.064860  ...              1.007583              0.946654
# 22               0.594417  ...              1.061300              1.119708
# 23               1.184821  ...              1.110380              1.030298
# 24               1.064603  ...              1.113845              0.970649
# 25               1.545676  ...              1.458392              1.366144
# 26               1.545966  ...              1.458386              1.441821
# 27               1.705617  ...              1.642060              1.598928
# 28               1.979148  ...              2.040461              2.163136
# 29               0.865638  ...              1.009078              1.094866
# ..                    ...  ...                   ...                   ...
# 154              1.540824  ...              1.487141              1.463748
# 155              1.299523  ...              1.531970              1.579539
# 156              1.564220  ...              1.463837              1.399823
# 157              1.159808  ...              1.482044              1.569790
# 158              1.728563  ...              1.710439              1.592733
# 159              1.133782  ...              1.066804              0.998202
# 160              0.645396  ...              1.056988              1.089954
# 161              1.067855  ...              1.033394              1.002213
# 162              1.098141  ...              1.028392              0.992178
# 163              1.098023  ...              1.028393              0.961935
# 164              1.160517  ...              1.073949              0.994462
# 165              1.099705  ...              1.780974              1.779629
# 166              1.816745  ...              1.913026              1.677808
# 167              0.192518  ...              1.551012              1.463202
# 168              1.588710  ...              1.665567              1.806122
# 169              2.360556  ...              2.485841              2.681103
# 170              2.588382  ...              2.342557              2.149186
# 171              1.144093  ...              1.931770              2.095400
# 172              2.154195  ...              2.166005              1.992719
# 173              0.443451  ...              0.413240              0.383541
# 174              2.334549  ...              2.274678              2.160654
# 175              1.893842  ...              1.927645              1.881513
# 176              1.603638  ...              1.873813              1.934053
# 177              1.871747  ...              1.772751              1.704578
# 178              2.485372  ...              2.389768              2.258438
# 179              1.233188  ...              1.487513              1.594454
# 180              3.126423  ...              2.822740              2.585002
# 181              2.823129  ...              2.974426              3.209140
# 182              1.569601  ...              1.499064              1.426719
# 183              1.304645  ...              1.505028              1.556876
#
#      c_1_1 elastic constant  c_1_2 elastic constant  c_1_3  elastic constant  \
# 0                     124.2                    93.9                     93.9
# 1                     116.8                    60.1                     60.1
# 2                     116.8                    60.1                     60.1
# 3                       6.7                    63.8                     63.8
# 4                     113.8                    61.6                     61.6
# 5                      74.5                    76.6                     76.6
# 6                      90.1                    70.7                     70.7
# 7                     137.2                   139.0                    139.0
# 8                     168.3                   127.0                    127.0
# 9                     107.9                    56.9                     56.9
# 10                    107.9                    56.9                     56.9
# 11                     44.0                    36.7                     36.7
# 12                     67.7                    51.9                     51.9
# 13                     29.2                    53.6                     53.6
# 14                    127.1                    81.4                     81.4
# 15                    201.6                   169.5                    169.5
# 16                    236.5                   165.7                    165.7
# 17                     95.5                    78.5                     78.5
# 18                     95.5                    78.5                     78.5
# 19                    275.8                   159.0                    159.0
# 20                    169.9                   122.6                    122.6
# 21                    124.2                    93.9                     93.9
# 22                     95.0                   101.2                    101.2
# 23                    119.4                    89.9                     89.9
# 24                    115.8                    88.2                     88.2
# 25                    169.9                   122.6                    122.6
# 26                    169.9                   122.6                    122.6
# 27                    180.4                   117.1                    117.1
# 28                    243.4                   129.6                    129.6
# 29                    100.5                    76.4                     76.4
# ..                      ...                     ...                      ...
# 154                   129.5                   103.2                    103.2
# 155                   114.5                    97.8                     97.8
# 156                   110.1                    76.9                     76.9
# 157                    95.6                   108.8                    108.8
# 158                    88.4                    74.4                     74.4
# 159                   122.9                    92.9                     92.9
# 160                    70.7                    72.2                     72.2
# 161                   104.3                    57.9                     57.9
# 162                   113.8                    61.7                     61.7
# 163                   113.8                    61.7                     61.7
# 164                   187.9                   157.8                    157.8
# 165                   137.6                   149.8                    149.8
# 166                   174.4                   123.7                    123.7
# 167                   110.4                    99.8                     99.8
# 168                   231.3                   136.7                    136.7
# 169                   456.3                   167.4                    167.4
# 170                   177.9                   115.9                    115.9
# 171                    42.7                   115.8                    115.8
# 172                   248.7                   147.6                    147.6
# 173                    49.7                    42.3                     42.3
# 174                   246.7                   200.5                    200.5
# 175                   295.2                   156.5                    156.5
# 176                    39.5                   116.6                    116.6
# 177                   236.6                   177.0                    177.0
# 178                   358.6                   261.4                    261.4
# 179                   116.3                   108.1                    108.1
# 180                   216.7                   138.5                    138.5
# 181                   519.9                   202.2                    202.2
# 182                   103.8                    77.2                     77.2
# 183                   114.8                   102.6                    102.6
#
#      c_4_4  elastic constant  Shear modulus  Bulk modulus  Cohesive energy  \
# 0                       46.4           33.9         104.0         2.850000
# 1                       31.7           30.4          79.0         3.360000
# 2                       31.7           30.4          79.0         3.360000
# 3                       23.3            2.6          44.8         3.254529
# 4                       31.6           29.4          79.0         3.360000
# 5                       39.4           23.2          75.9         3.301618
# 6                       33.1           23.7          77.2         3.318317
# 7                       87.7           52.3         138.4         3.502145
# 8                       75.1           53.3         140.8         3.524568
# 9                       32.9           29.9          73.9         3.359280
# 10                      32.9           29.9          73.9         3.359280
# 11                       7.2            5.8          39.1         2.030004
# 12                      21.8           16.2          57.2         2.012609
# 13                      17.8            5.8          45.5         3.522957
# 14                      36.4           31.0          96.6         3.579999
# 15                      46.0           34.0         180.2         3.924218
# 16                     148.9          103.5         189.3         4.383116
# 17                      19.1           14.9          84.2         3.368458
# 18                      19.1           14.9          84.2         3.368458
# 19                     108.2           88.3         197.9         4.384879
# 20                      76.2           55.2         138.4         3.540000
# 21                      46.4           33.9         104.0         2.850000
# 22                      65.4           38.0          99.1         3.291087
# 23                      49.7           35.7          99.7         3.320667
# 24                      44.3           32.1          97.4         2.849997
# 25                      76.2           55.2         138.4         3.540218
# 26                      76.2           55.2         138.4         3.540218
# 27                      70.7           55.1         138.2         3.539804
# 28                      27.6           39.3         167.5         7.465424
# 29                      58.6           40.0          84.4         4.839938
# ..                       ...            ...           ...              ...
# 154                     69.6           47.0         112.0         5.989192
# 155                     63.5           41.4         103.4         5.992671
# 156                     64.3           45.2          88.0         6.438777
# 157                     41.7           22.4         104.4         6.417554
# 158                     44.5           29.5          79.1         6.580394
# 159                     45.1           33.1         102.9         2.849995
# 160                     29.5           17.4          71.7         3.546300
# 161                     27.7           25.9          73.4         3.579980
# 162                     31.2           29.1          79.1         2.645980
# 163                     31.2           29.1          79.1         2.645980
# 164                     42.6           31.6         167.8         3.930002
# 165                     81.9           46.7         145.7         3.502243
# 166                     78.5           57.2         140.6         3.539982
# 167                     80.8           50.6         103.3         4.195710
# 168                    117.8           89.6         168.2         4.289998
# 169                    115.3          127.0         263.7         6.810004
# 170                     77.7           59.0         136.6         6.656086
# 171                     93.3           41.4          91.4         4.367057
# 172                    126.2           95.9         181.3         4.449992
# 173                     14.8           10.4          44.8         2.019996
# 174                     55.7           42.7         215.9         3.910418
# 175                    102.1           89.0         202.7         1.749071
# 176                     83.7           34.8          90.9         1.731120
# 177                     72.1           55.2         196.9         3.909996
# 178                     78.3           66.4         293.8         5.769960
# 179                     77.4           48.1         110.8         4.850182
# 180                     98.6           74.8         164.6         8.596943
# 181                    159.0          158.9         308.1         8.759994
# 182                     45.1           32.4          86.1         6.351768
# 183                     64.6           41.2         106.7         6.342020
#
#      Vacancy formation energy
# 0                    1.101970
# 1                    0.707500
# 2                    0.706920
# 3                    0.674610
# 4                    0.673730
# 5                    0.561913
# 6                    0.717003
# 7                    1.045832
# 8                    1.274232
# 9                    0.672020
# 10                   0.671630
# 11                   0.307186
# 12                   0.397526
# 13                   0.715761
# 14                   0.715071
# 15                   1.128352
# 16                   1.437568
# 17                   0.631642
# 18                   0.631542
# 19                   1.553546
# 20                   1.272000
# 21                   1.101970
# 22                   0.842234
# 23                   0.841934
# 24                   1.102053
# 25                   1.271982
# 26                   1.271982
# 27                   1.319897
# 28                   2.770376
# 29                   1.392751
# ..                        ...
# 154                  1.461969
# 155                  0.955669
# 156                  2.208934
# 157                  0.528834
# 158                  1.555191
# 159                  1.094895
# 160                  0.748110
# 161                  0.740990
# 162                  0.662420
# 163                  0.661670
# 164                  0.992598
# 165                  1.392518
# 166                  1.275718
# 167                  1.595002
# 168                  1.673602
# 169                  2.953096
# 170                  3.100296
# 171                  1.892308
# 172                  1.704208
# 173                  0.590064
# 174                  1.243442
# 175                  1.119020
# 176                  1.230280
# 177                  1.548634
# 178                  1.530339
# 179                  1.351190
# 180                  3.741906
# 181                  3.575706
# 182                  1.819047
# 183                  1.449747
#
# [184 rows x 22 columns]

# %%
import seaborn as sns
sns.set()

sns.clustermap(df_cubic.corr(), center=0, cmap="vlag")

# %%
# determine number of surfaces computed for materials with hexagonal lattices
sn_array = [len(d['surf_name']) for d in data if get_lattice(d['sg']) == 'hexagonal']

# Count the number of points for each number of surfaces
sn_hist = Counter()
for sn in sn_array:
     sn_hist[sn] += 1            
            
# Sort the Bravais lattices from the largest number of points to the smalest
sn_sorted = [item[0] for item in sorted(sn_hist.items() , reverse=True, key=lambda x: x[1])]         
            
# Plot the corresponding histogram
plt.rcParams['figure.figsize'] = [15, 5]
plt.title("Number of data point corresponding to each nuber of surfaces for materials with hexagonal lattices")
sns.set(style="darkgrid")
ax = sns.countplot(x=sn_array, order=sn_sorted)

# %%
# determine number of vacancy energies computed for materials with hexagonal lattices and 29 surfaces
ve_array = [len(d['defect_val']) for d in data if get_lattice(d['sg']) == 'hexagonal' and len(d['surf_name']) == 29]

# Count the number of points for each number of surfaces
ve_hist = Counter()
for ve in ve_array:
     ve_hist[ve] += 1            
            
# Sort the Bravais lattices from the largest number of points to the smalest
ve_sorted = [item[0] for item in sorted(ve_hist.items() , reverse=True, key=lambda x: x[1])]         
            
# Plot the corresponding histogram
plt.rcParams['figure.figsize'] = [15, 5]
plt.title("Number of data point corresponding to number of vacancy energies computed for materials with hexagonal lattices and 29 surfaces")
sns.set(style="darkgrid")
ax = sns.countplot(x=ve_array, order=ve_sorted)

# %%
# show all the materials with number of vacancy energy larger than 1
import pprint
pprint.pprint([{d['formula'] : d['defect_val']} for d in data if get_lattice(d['sg']) == 'hexagonal' and len(d['surf_name']) == 29 and len(d['defect_val']) > 0])
# Out:
# [{'Ag': [1.086429999999973, 1.0916199999999434]},
#  {'Ag': [1.0748000000000046]},
#  {'Cu': [1.2765323000001332, 1.2741323000000535]},
#  {'Cu': [1.275932299999829]},
#  {'Pb': [0.3062960999999942]},
#  {'Co': [1.4485676500000677]},
#  {'Co': [0.906567649999924,
#          -0.0180323500003583,
#          2.5105676499997385,
#          -0.17323235000005344,
#          2.5902676499999684,
#          0.00046764999977266797,
#          0.3463676500000288]},
#  {'Al5Co2': [0.15096764999996548,
#              0.3121676499999735,
#              0.09256765000007317,
#              0.42766764999985707,
#              1.4524676499999982]},
#  {'Co': [1.494445699999865]},
#  {'Cu': [1.2533000000000447, 1.2668000000000665]},
#  {'Cu': [1.2473999999999341]},
#  {'Cu': [1.2533000000000447, 1.2668000000000665]},
#  {'Cu': [1.2473999999999341]},
#  {'Ag': [1.086429999999973, 1.0916199999999434]},
#  {'Ag': [1.0748000000000046]},
#  {'CuAg3': [0.6323000000001775, 0.34560000000006763]},
#  {'Cu': [0.8269335000000111, 0.8366334999998499]},
#  {'Cu': [0.820533500000026]},
#  {'Ag': [1.0865031000000238, 1.0916930999999943]},
#  {'Ag': [1.074823100000068]},
#  {'CuAg3': [1.9343334999998816, 0.6573335000000653]},
#  {'Cu': [1.2532816999999947, 1.2667817000000166]},
#  {'Cu': [1.2473817000001115]},
#  {'Cu': [1.28119650000014, 1.3013965000000716]},
#  {'Cu': [1.2506965000000654]},
#  {'Ti': [8.141351000000146, 9.80355100000013]},
#  {'Ti': [1.5737510000000619]},
#  {'Ti3Al': [3.0749518999998737, 2.6526518999999236]},
#  {'Fe': [1.649864900000087]},
#  {'Cu': [1.2532816999999947, 1.2667817000000166]},
#  {'Cu': [1.2473817000001115]},
#  {'Ni': [1.5588383999999893]},
#  {'Fe': [1.9945060000001416]},
#  {'Ni': [1.3423408999999396]},
#  {'Cr': [2.210551199999876]},
#  {'Fe': [2.0521638000000912]},
#  {'Ni': [1.4555578000001246]},
#  {'Cr': [2.217589699999934]},
#  {'Fe': [1.649864900000087]},
#  {'Ni': [1.5588383999999893]},
#  {'Mg': [0.8697888500000142]},
#  {'Mg': [0.8677688499999983, 0.8373788500000439]},
#  {'Co': [1.4944455999998656]},
#  {'Ni': [1.5333000000000991]},
#  {'Ni': [1.5333000000000991]},
#  {'Co': [1.4944455999998656]},
#  {'Ni': [1.5333000000000991]},
#  {'Co': [1.4944455999998656]},
#  {'Co': [1.49455064999984]},
#  {'Ni': [1.5333000000000991]},
#  {'Co': [1.49455064999984]},
#  {'Ni': [1.5333000000000991]},
#  {'Co': [1.49455064999984]},
#  {'Ni': [1.5164999999999962]},
#  {'Ni': [0.6722648000000788]},
#  {'Ni': [1.5333000000000991]},
#  {'Ni': [1.6083999999998921]},
#  {'H2': [0.0]},
#  {'H2': [4.738939999999957]},
#  {'H2': [0.0]},
#  {'Ag': [1.0864063999999982, 1.0915963999999687]},
#  {'Ag': [1.0748264000000174]},
#  {'H2': [1.1944566999999968]},
#  {'H2': [-1.823993300000033]},
#  {'H2': [1.1944566999999968]},
#  {'Ag': [1.0864063999999982, 1.0915963999999687]},
#  {'Ag': [1.0748264000000174]},
#  {'H2': [1.1944566999999968]},
#  {'H2': [-1.823993300000033]},
#  {'H2': [1.1944566999999968]},
#  {'Ag': [1.0215961000000453, 1.0324660999999997]},
#  {'Ag': [1.0305460999999587]},
#  {'Sm': [0.36951250000004876]},
#  {'SmAl3': [4.2206512000000265, 1.2103512000001109]},
#  {'Sm3Al': [2.2607911999999777, 2.27040119999993]},
#  {'Fe': [1.6519176999999887]},
#  {'AlFe2': [31.47079450000002, 23.37439449999989]},
#  {'AlFe': [-15.608675500000109, -10.567615500000093]},
#  {'Al3Fe': [0.2250177000000564, 1.4798176999999884]},
#  {'Mg': [0.8747639500000208]},
#  {'Mg': [0.8753939500000218, 0.8516939500000025]},
#  {'Au': [0.9837546999999609]},
#  {'Cu': [1.0340837999999573, 1.0478837999999038]},
#  {'Cu': [1.0330838000002083]},
#  {'Cu': [1.1885470000001086, 1.2021470000001053]},
#  {'Cu': [1.1992469999999238]},
#  {'Cu': [1.0341837999999322, 1.0478837999999038]},
#  {'Cu': [1.0330838000002083]},
#  {'Zr': [2.2696340000000577]},
#  {'Cu': [1.0341837999999322, 1.0478837999999038]},
#  {'Cu': [1.0330838000002083]},
#  {'Zr': [2.2696340000000577]},
#  {'Fe': [1.649864900000087]},
#  {'Fe': [1.5951996999999665]},
#  {'Fe': [1.6519176999999887]},
#  {'C': [-1.9416215000000245]},
#  {'C': [0.9929784999999076, 0.9929784999999076]},
#  {'C': [-1.8488215000001271,
#         -1.9315215000000587,
#         -1.80962150000019,
#         -1.9389215000000202]},
#  {'C': [-1.8871215000000627, -1.9193215000001653]},
#  {'C': [-1.9216215000000427, -1.8190214999998768, -1.9249214999998965]},
#  {'C': [0.9836285000000378]},
#  {'C': [0.9929784999999076, 0.9929784999999076]},
#  {'Fe2C': [-3.252121500000072, 2.2559784999999413]},
#  {'Fe3C': [3.668678500000255, 3.3557784999999005]},
#  {'Fe7C3': [2.3302177000002517,
#             2.6288177000003303,
#             2.4574177000001542,
#             2.153917700000169]},
#  {'Fe': [1.883200000000019]},
#  {'Fe': [1.6519176999999887]},
#  {'Cu': [1.0884808000001445, 1.1042808000000437]},
#  {'Cu': [1.0866807999999142]},
#  {'Mg': [0.9255383999999758]},
#  {'Mg': [0.9256284000000328, 0.9016284000000319]},
#  {'Mg': [0.8747639500000208]},
#  {'Mg': [0.8753939500000218, 0.8516939500000025]},
#  {'Na': [0.3303753000000249]},
#  {'Na': [0.26678530000002, 0.25226530000001546]},
#  {'Ni': [1.675091200000022]},
#  {'Ni': [1.675091200000022]},
#  {'Ni': [1.4157025999998476]},
#  {'Ni': [1.675091200000022]},
#  {'Zr': [2.2696340000000577]},
#  {'ZrNi3': [3.7325340000002756, -0.7250659999999085]},
#  {'Ni': [1.675091200000022]},
#  {'Zr': [2.2696340000000577]},
#  {'ZrNi3': [3.7325340000002756, -0.7250659999999085]},
#  {'Ni': [1.675091200000022]},
#  {'Zr': [2.2696340000000577]},
#  {'ZrNi3': [3.770534000000059, -0.6799659999998608]},
#  {'Ru': [2.1426625000000117]},
#  {'Ti': [1.629525666666857, 0.6283256666667034]},
#  {'Ti': [1.515725666666774]},
#  {'Fe': [1.6519176999999887]},
#  {'Zr': [1.474669500000112]},
#  {'Zr': [2.2696340000000577]},
#  {'Zr': [1.6854909999998862]},
#  {'Ag': [1.1078550000000078, 1.1104449999999488]},
#  {'Ag': [1.1200349999999517]},
#  {'Au': [1.0192976999999939]},
#  {'Co': [1.8829738500001705]},
#  {'Cu': [1.2933176000000084, 1.300917600000147]},
#  {'Cu': [1.3171175999999458]},
#  {'Fe': [1.595501700000093]},
#  {'Mg': [0.6598058500000046]},
#  {'Mg': [0.651815849999998, 0.6495158500000069]},
#  {'Ni': [1.6811080000000604]},
#  {'Pb': [0.6044439000000494]},
#  {'H2': [1.1746596000000498]},
#  {'H2': [0.6578296000000226]},
#  {'H2': [1.1746596000000498]},
#  {'Ti': [-0.4957096666666603, -0.09530966666666973]},
#  {'Ti': [1.7385903333334154]},
#  {'Zr': [1.8815470000000625]}]

# %%
# Create the material array
formula_array = []
for d in data:
    formula_array.append(d['formula'])

# Count the number of points for each material
formula_hist = Counter()
for formula in formula_array:
     formula_hist[formula] += 1

# Sort the materials from the largest number of points to the smalest
formula_sorted = [item[0] for item in sorted(formula_hist.items() , reverse=True, key=lambda x: x[1])]
sg_sorted

# %%
plt.rcParams['figure.figsize'] = [15, 25]
ax = sns.countplot(y=formula_array, order = formula_sorted)

# %%
a = np.sort(np.abs(np.asarray('-1_3_-2'.split('_'), dtype=int)))
print(a)
b = np.sort(np.abs(np.asarray('2_3_-1'.split('_'), dtype=int)))
print(b)
if (a == b).all():
    print(1)
if all([i == j for i,j in zip(a,b)]):
    print(1)
# Out:
# [1 2 3]
# [1 2 3]
# 1
# 1

# %%
# 100, 110, 210, 310, 320, 111, 211, 311, 221, 321, 331, 322, 332
